# %%
import importlib
import os
os.chdir('/home/armin/code/SinanSeyhan/green-electricity-project')
consumption_vap_module = importlib.import_module("green-electricity-project.consumption_viz_and_pred", package=True)

# %%
consumption = consumption_vap_module.ConsumptionVaP('EU')

# %%
consumption.run_viz_and_pred()
# Out:
# 2022-06-09 20:30:39.552
# ...
#   command:
#
#     streamlit run /home/armin/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2022-06-09 20:30:40.594 n_changepoints greater than number of observations. Using 22.
# Initial log joint probability = -29.4657
# Iteration  1. Log joint probability =    23.7881. Improved by 53.2538.
# Iteration  2. Log joint probability =    62.7797. Improved by 38.9916.
# Iteration  3. Log joint probability =    72.2031. Improved by 9.42339.
# Iteration  4. Log joint probability =    72.2213. Improved by 0.0182171.
# Iteration  5. Log joint probability =    72.3223. Improved by 0.100926.
# Iteration  6. Log joint probability =    72.3243. Improved by 0.00199826.
# Iteration  7. Log joint probability =    72.3841. Improved by 0.0598806.
# Iteration  8. Log joint probability =    73.3091. Improved by 0.924996.
# Iteration  9. Log joint probability =    73.3314. Improved by 0.0222512.
# ...

# %%
import pandas as pd

# %%
ls
# Out:
# app.py                      notebooks/    README.md          scripts/
# green-electricity-project/  packages.txt  README_PROJECT.md  setup.py
# Makefile                    Procfile      requirements.txt   setup.sh
# MANIFEST.in                 raw_data/     runtime.txt        tests/

# %%
for i in range(len(consumption.forecast_list)):
    consumption.forecast_list[i].to_csv(f'raw_data/forecast_consumption_eu/forecast_consumption_eu_{i:02d}')

# %%
forecast_files = sorted(os.listdir('raw_data/forecast_consumption_eu/'))

# %%
forecast_files
# Out:
# ['forecast_consumption_eu_00',
#  'forecast_consumption_eu_01',
#  'forecast_consumption_eu_02',
#  'forecast_consumption_eu_03',
#  'forecast_consumption_eu_04',
#  'forecast_consumption_eu_05',
#  'forecast_consumption_eu_06',
#  'forecast_consumption_eu_07',
#  'forecast_consumption_eu_08',
#  'forecast_consumption_eu_09',
#  'forecast_consumption_eu_10',
#  'forecast_consumption_eu_11',
#  'forecast_consumption_eu_12',
#  'forecast_consumption_eu_13',
#  'forecast_consumption_eu_14',
#  'forecast_consumption_eu_15',
#  'forecast_consumption_eu_16',
#  'forecast_consumption_eu_17',
#  'forecast_consumption_eu_18',
#  'forecast_consumption_eu_19',
#  'forecast_consumption_eu_20',
#  'forecast_consumption_eu_21',
#  'forecast_consumption_eu_22']

# %%
forecasts_loaded = []
for i in forecast_files:
    path = ''.join(('raw_data/forecast_consumption_eu/', i))
    forecasts_loaded.append(pd.read_csv(path))

# %%
forecasts_loaded
# Out:
# [    Unnamed: 0          ds         trend    yhat_lower    yhat_upper  \
#  0            0  1990-12-31  3.570751e+06  1.475858e+08  1.538730e+08
#  1            1  1991-12-31  3.526806e+06  1.458118e+08  1.521124e+08
#  2            2  1992-12-30  3.504282e+06  1.448309e+08  1.510811e+08
#  3            3  1993-12-31  3.760103e+06  1.556021e+08  1.618202e+08
#  4            4  1994-12-31  3.805788e+06  1.576189e+08  1.638525e+08
#  5            5  1995-12-31  4.103065e+06  1.702575e+08  1.766465e+08
#  6            6  1996-12-30  4.177548e+06  1.731874e+08  1.795272e+08
#  7            7  1997-12-31  3.958502e+06  1.638504e+08  1.701421e+08
#  8            8  1998-12-31  4.148094e+06  1.722062e+08  1.787188e+08
#  9            9  1999-12-31  4.134830e+06  1.714606e+08  1.778620e+08
#  10          10  2000-12-30  4.395266e+06  1.823148e+08  1.888700e+08
#  11          11  2001-12-31  4.429782e+06  1.838949e+08  1.903938e+08
# ...
