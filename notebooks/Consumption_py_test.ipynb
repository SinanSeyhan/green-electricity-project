# %%
import importlib
import os
os.chdir('..')
consumption_module = importlib.import_module("green-electricity-project.consumption", package=True)

# %%
consumption_germany = consumption_module.Consumption(country=['Germany'], get_quartiles=True, quartiles_asc=True)

# %%
consumption_germany.prepare_consumption_and_export()
# Out:
#                  1990         1991         1992         1993         1994  \
# quartile
# 1         225656000.0  246110000.0  234612000.0  213188000.0  217680000.0
# 2         170808000.0  139618000.0  147126000.0  154064000.0  157669000.0
# 3         224932000.0  225493000.0  224119000.0  228869000.0  226765000.0
# 4         216479000.0  214513000.0  211912000.0  202200000.0  201403000.0
#
#                  1995         1996         1997         1998         1999  \
# quartile
# 1         226097000.0  223166000.0  226013000.0  225714000.0  222803000.0
# 2         158330000.0  166930000.0  163136000.0  164857000.0  161968000.0
# 3         230294000.0  240684000.0  238571000.0  241752000.0  245279000.0
# 4         204724000.0  201129000.0  206297000.0  208293000.0  212367000.0
#
#           ...         2011         2012         2013         2014  \
# quartile  ...
# 1         ...  213015000.0  207221000.0  203321000.0  203516000.0
# ...

# %%
consumption_germany.cons_df_by_energy_bal.T.plot(figsize = (20, 10) )
# Out:
# <AxesSubplot:>

# %%
consumption_eu = consumption_module.Consumption(country=['EU'], get_quartiles=True, quartiles_asc=True)

# %%
consumption_eu.prepare_consumption_and_export()
# Out:
#                   1990          1991          1992          1993  \
# quartile
# 1         1.021236e+09  1.025977e+09  9.792116e+08  9.282550e+08
# 2         6.393703e+08  6.081131e+08  6.050252e+08  6.114273e+08
# 3         5.148150e+08  5.243090e+08  5.307170e+08  5.405750e+08
# 4         1.266197e+09  1.264829e+09  1.256230e+09  1.245774e+09
#
#                   1994          1995          1996          1997  \
# quartile
# 1         9.551165e+08  9.849628e+08  1.005940e+09  1.014787e+09
# 2         6.094920e+08  6.342012e+08  6.498944e+08  6.441455e+08
# 3         5.469840e+08  5.548520e+08  5.867500e+08  5.827160e+08
# 4         1.270390e+09  1.299786e+09  1.328573e+09  1.368188e+09
#
#                   1998          1999  ...          2011          2012  \
# quartile                              ...
# 1         1.022942e+09  1.025846e+09  ...  1.025604e+09  9.893114e+08
# 2         6.572872e+08  6.538163e+08  ...  7.089663e+08  7.081747e+08
# ...

# %%
consumption_eu.cons_df_by_energy_bal.T.plot(figsize = (20, 10) )
# Out:
# <AxesSubplot:>

# %%
consumption_benelux = consumption_module.Consumption(country=['Belgium', 'Netherlands', 'Luxembourg'], get_quartiles=True, quartiles_asc=True)

# %%
consumption_benelux.prepare_consumption_and_export()
# Out:
#                 1990        1991        1992        1993         1994  \
# quartile
# 1         66928000.0  68657000.0  69305000.0  69696000.0   72664000.0
# 2         35266000.0  34824000.0  35795000.0  34536000.0   37696000.0
# 3         34663000.0  36742000.0  37484000.0  38740000.0   39581000.0
# 4         93668000.0  95557000.0  98222000.0  98807000.0  104210000.0
#
#                  1995         1996         1997         1998         1999  \
# quartile
# 1          74692000.0   75724000.0   77608000.0   80386000.0   81593000.0
# 2          38377000.0   39782000.0   40426000.0   41850000.0   44334000.0
# 3          40855000.0   42251000.0   42296000.0   43144000.0   43745000.0
# 4         106196000.0  109362000.0  114414000.0  118719000.0  120805000.0
#
#           ...          2011          2012          2013          2014  \
# quartile  ...
# 1         ...  8.445429e+07  7.830757e+07  8.002451e+07  7.693501e+07
# ...

# %%
consumption_benelux.cons_df_by_energy_bal.T.plot(figsize = (20, 10) )
# Out:
# <AxesSubplot:>
