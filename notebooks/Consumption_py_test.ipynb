# %%
import importlib
import os
os.chdir('..')
consumption = importlib.import_module("green-electricity-project.consumption", package=True).Consumption(country=['EU'], get_quartiles=False, quartiles_asc=False)

# %%
consumption.prepare_consumption_and_export()
# Out:
#                                                            1990         1991  \
# energy_balance
# Distributionlosses                                  151012000.0  148801000.0
# Energysector-blastfurnaces-energyuse                        0.0      86000.0
# Energysector-browncoalbriquettesandpeatbriquett...    9147000.0    9259000.0
# Energysector-charcoalproductionplants-energyuse             0.0          0.0
# Energysector-coalliquefactionplants-energyuse               0.0          0.0
# Energysector-coalmines-energyuse                     22925000.0   22059000.0
# Energysector-cokeovens-energyuse                      2452000.0    2427000.0
# Energysector-electricityandheatgeneration-energ...  142880351.0  143637314.0
# Energysector-energyuse                              100736000.0  105596000.0
# Energysector-gas-to-liquidsplants-energyuse                 0.0          0.0
# Energysector-gasificationplantsforbiogas-energyuse          0.0          0.0
# ...

# %%
consumption.cons_df_by_energy_bal.sort_values(by='2019', ascending = False).head(10).T.plot(figsize = (20, 10) )
# Out:
# <AxesSubplot:>
