# %%
# !pip install pystan

# !pip install prophet

from prophet import Prophet
# Out:
# ...
#   Using cached aiohttp-3.8.1-cp38-cp38-macosx_10_9_x86_64.whl (574 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 KB 1.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 5.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.8/196.8 KB 5.0 MB/s eta 0:00:0000:01
# ...
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# ...
#   Using cached aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# ...
#   Using cached yarl-1.7.2-cp38-cp38-macosx_10_9_x86_64.whl (121 kB)
# ...
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 KB 1.8 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.1 is available.
# You should consider upgrading via the '/Users/pratimas/.pyenv/versions/3.8.12/envs/green-electricity-project/bin/python -m pip install --upgrade pip' command.
# ...
#   Using cached prophet-1.0.1-py3-none-any.whl
# ...
